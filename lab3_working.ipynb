# %%
pwd
# Out:
# '/Users/daniellamesler/Documents/UW/WINTER_19/458/LAB3'

# %%
# Imports
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame
import pandas as pd
import dbfread as dbf
import fiona

# %%
# Reading in shapefile data

saep_bg10 = gpd.read_file('saep_bg10/saep_bg10.shp')
saep_bg10.head()
# Out:
#   STATEFP10 COUNTYFP10 TRACTCE10 BLKGRPCE10       GEOID10     NAMELSAD10  \
# 0        53        001    950100          1  530019501001  Block Group 1
# 1        53        001    950100          2  530019501002  Block Group 2
# 2        53        001    950100          3  530019501003  Block Group 3
# 3        53        001    950200          1  530019502001  Block Group 1
# 4        53        001    950200          2  530019502002  Block Group 2
#
#   MTFCC10 FUNCSTAT10  INTPTLON10  INTPTLAT10  ...  OHU2014  OHU2015  OHU2016  \
# 0   G5030          S -118.398815   47.150809  ...  277.494  279.680  287.530
# 1   G5030          S -118.351143   47.135101  ...  524.831  521.228  517.427
# 2   G5030          S -118.382148   47.138222  ...  246.344  243.965  242.033
# 3   G5030          S -118.219484   46.874027  ...  208.923  203.761  205.502
# 4   G5030          S -118.522323   46.968569  ...  285.857  286.251  278.398
#
# ...

# %%
pwd
# Out:
# '/Users/daniellamesler/Documents/UW/WINTER_19/458/LAB3'

# %% [markdown]
# Okay sorry I just got home. Here are a few more suggestions based on a closer search.
# Rather than setting the encoding on a separate like like you did, try putting "encoding = 'utf-8' " or whatever you need it to be in the read_file function as an argument, after the filename. This is an argument used in Fiona and it should function in geopandas.
# Try some variations on that, if it doesn't work, try importing Fiona directly, then use the fiona.open() function, where you can type the filename then the same encoding arg from above. If that works it will make you an object, but I think it will be a "collection" not a geodataframe, so you can look for how to convert it up to geodataframe hopefully?
